# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
ficheros=[]
datos=[]

# %%
with open("software/salidas/greedy.txt",'r') as f:
    lines= f.readlines()

lines=lines[1:]

i=0
while i < len(lines):
    ficheros.append(lines[i].replace('data/','').replace('\n',''))
    datos.append(list(map(float,lines[i+1].split('\t'))))
    i+=2

# %%
datos
# Out:
# [[7642.27, 0.001893],
#  [7610.42, 0.001375],
#  [7574.39, 0.001293],
#  [7535.96, 0.001304],
#  [7551.52, 0.001281],
#  [7540.14, 0.001284],
#  [7623.65, 0.001278],
#  [7594.62, 0.0014],
#  [7625.94, 0.001367],
#  [7547.25, 0.001351],
#  [11099332.620328, 0.319017],
#  [11149879.733826, 0.313017],
#  [11119613.974858, 0.303374],
#  [11106996.970212, 0.311278],
#  [11114220.292214, 0.306411],
#  [11132801.799043, 0.306542],
#  [11130608.965587, 0.310595],
#  [11110673.520354, 0.318429],
#  [11156328.082493, 0.306362],
#  [11109767.818822, 0.296905],
#  [42959794.0, 2.566065],
#  [66493045.0, 3.67213],
#  [66449858.0, 3.767131],
#  [66468837.0, 3.78725],
#  [94929882.0, 5.183856],
#  [24617010.0, 1.501668],
#  [94979205.0, 5.582157],
#  [24547293.0, 1.464132],
#  [43056071.0, 2.546235],
#  [42958639.0, 2.569214]]

# %%
df = pd.DataFrame({'File':[],'Diversity':[],'Time':[]})

# %%
for i in range(len(ficheros)):
    new_row={'File':ficheros[i][:-4],'Diversity':datos[i][0],'Time':datos[i][1]}
    df=df.append(new_row, ignore_index=True)

# %%
df.index=df.File
df.drop(columns=['File'],inplace=True)

# %%
df
# Out:
#                         Diversity      Time
# File
# MDG-a_10_n500_m50    7.642270e+03  0.001893
# MDG-a_1_n500_m50     7.610420e+03  0.001375
# MDG-a_2_n500_m50     7.574390e+03  0.001293
# MDG-a_3_n500_m50     7.535960e+03  0.001304
# MDG-a_4_n500_m50     7.551520e+03  0.001281
# MDG-a_5_n500_m50     7.540140e+03  0.001284
# MDG-a_6_n500_m50     7.623650e+03  0.001278
# MDG-a_7_n500_m50     7.594620e+03  0.001400
# MDG-a_8_n500_m50     7.625940e+03  0.001367
# MDG-a_9_n500_m50     7.547250e+03  0.001351
# MDG-b_21_n2000_m200  1.109933e+07  0.319017
# MDG-b_22_n2000_m200  1.114988e+07  0.313017
# MDG-b_23_n2000_m200  1.111961e+07  0.303374
# MDG-b_24_n2000_m200  1.110700e+07  0.311278
# MDG-b_25_n2000_m200  1.111422e+07  0.306411
# MDG-b_26_n2000_m200  1.113280e+07  0.306542
# MDG-b_27_n2000_m200  1.113061e+07  0.310595
# MDG-b_28_n2000_m200  1.111067e+07  0.318429
# MDG-b_29_n2000_m200  1.115633e+07  0.306362
# MDG-b_30_n2000_m200  1.110977e+07  0.296905
# MDG-c_10_n3000_m400  4.295979e+07  2.566065
# MDG-c_13_n3000_m500  6.649304e+07  3.672130
# MDG-c_14_n3000_m500  6.644986e+07  3.767131
# MDG-c_15_n3000_m500  6.646884e+07  3.787250
# MDG-c_19_n3000_m600  9.492988e+07  5.183856
# MDG-c_1_n3000_m300   2.461701e+07  1.501668
# MDG-c_20_n3000_m600  9.497920e+07  5.582157
# MDG-c_2_n3000_m300   2.454729e+07  1.464132
# MDG-c_8_n3000_m400   4.305607e+07  2.546235
# MDG-c_9_n3000_m400   4.295864e+07  2.569214

# %%
#df.to_csv('results/localSearch.csv')
#df.to_csv('results/localSearch2.csv')
df.to_csv('results/greedy.csv')
