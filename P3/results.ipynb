# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
ficheros=[]
datos=[]

# %%
#algoritmo='ES'
#algoritmo='ES-proporcional'
#algoritmo='BMB'
#algoritmo='ILS'
#algoritmo='ILS-ES'
#algoritmo='ILS-ES-proporcional'

# %%
with open("software/salidas/"+algoritmo+".txt",'r') as f:
    lines= f.readlines()

lines=lines[1:]

i=0
while i < len(lines):
    ficheros.append(lines[i].replace('data/','').replace('\n',''))
    datos.append(list(map(float,lines[i+1].split('\t'))))
    i+=2

# %%
datos
# Out:
# [[7707.51, 0.012247],
#  [7670.07, 0.006072],
#  [7605.52, 0.00734],
#  [7640.15, 0.004435],
#  [7506.45, 0.002631],
#  [7595.3, 0.007672],
#  [7513.32, 0.002595],
#  [7531.44, 0.00346],
#  [7609.81, 0.007511],
#  [7654.97, 0.006011],
#  [11155738.985299, 0.186285],
#  [11164122.435074, 0.184283],
#  [11177722.312113, 0.180047],
#  [11124330.872795, 0.175191],
#  [11181796.14402, 0.175225],
#  [11157826.838857, 0.176321],
#  [11165835.734422, 0.177808],
#  [11119034.565327, 0.174686],
#  [11163768.720372, 0.175868],
#  [11148372.956175, 0.174758],
#  [43031426.0, 0.514451],
#  [66556889.0, 0.602169],
#  [66646003.0, 0.598817],
#  [66693908.0, 0.605126],
#  [95013094.0, 0.672743],
#  [24637456.0, 0.418843],
#  [94941193.0, 0.664133],
#  [24595823.0, 0.416247],
#  [43042008.0, 0.515977],
#  [43044732.0, 0.51509]]

# %%
df = pd.DataFrame({'File':[],'Diversity':[],'Time':[]})

# %%
for i in range(len(ficheros)):
    new_row={'File':ficheros[i][:-4],'Diversity':datos[i][0],'Time':datos[i][1]}
    df=df.append(new_row, ignore_index=True)

# %%
df.index=df.File
df.drop(columns=['File'],inplace=True)

# %%
new_index=['MDG-a_'+str(i)+'_n500_m50' for i in range(1,11)]
new_index=new_index+['MDG-b_'+str(i)+'_n2000_m200' for i in range(21,31)]
new_index=new_index+['MDG-c_'+str(i)+'_n3000_m300' for i in range(1,3)]
new_index=new_index+['MDG-c_'+str(i)+'_n3000_m400' for i in range(8,11)]
new_index=new_index+['MDG-c_'+str(i)+'_n3000_m500' for i in range(13,16)]
new_index=new_index+['MDG-c_'+str(i)+'_n3000_m600' for i in range(19,21)]

# %%
df=df.reindex(new_index)
df
# Out:
#                         Diversity      Time
# File
# MDG-a_1_n500_m50     7.670070e+03  0.006072
# MDG-a_2_n500_m50     7.605520e+03  0.007340
# MDG-a_3_n500_m50     7.640150e+03  0.004435
# MDG-a_4_n500_m50     7.506450e+03  0.002631
# MDG-a_5_n500_m50     7.595300e+03  0.007672
# MDG-a_6_n500_m50     7.513320e+03  0.002595
# MDG-a_7_n500_m50     7.531440e+03  0.003460
# MDG-a_8_n500_m50     7.609810e+03  0.007511
# MDG-a_9_n500_m50     7.654970e+03  0.006011
# MDG-a_10_n500_m50    7.707510e+03  0.012247
# MDG-b_21_n2000_m200  1.115574e+07  0.186285
# MDG-b_22_n2000_m200  1.116412e+07  0.184283
# MDG-b_23_n2000_m200  1.117772e+07  0.180047
# MDG-b_24_n2000_m200  1.112433e+07  0.175191
# MDG-b_25_n2000_m200  1.118180e+07  0.175225
# MDG-b_26_n2000_m200  1.115783e+07  0.176321
# MDG-b_27_n2000_m200  1.116584e+07  0.177808
# MDG-b_28_n2000_m200  1.111903e+07  0.174686
# MDG-b_29_n2000_m200  1.116377e+07  0.175868
# MDG-b_30_n2000_m200  1.114837e+07  0.174758
# MDG-c_1_n3000_m300   2.463746e+07  0.418843
# MDG-c_2_n3000_m300   2.459582e+07  0.416247
# MDG-c_8_n3000_m400   4.304201e+07  0.515977
# MDG-c_9_n3000_m400   4.304473e+07  0.515090
# MDG-c_10_n3000_m400  4.303143e+07  0.514451
# MDG-c_13_n3000_m500  6.655689e+07  0.602169
# MDG-c_14_n3000_m500  6.664600e+07  0.598817
# MDG-c_15_n3000_m500  6.669391e+07  0.605126
# MDG-c_19_n3000_m600  9.501309e+07  0.672743
# MDG-c_20_n3000_m600  9.494119e+07  0.664133

# %%
df.to_csv('results/'+algoritmo+'.csv')
