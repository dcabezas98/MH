# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
ficheros=[]
datos=[]

# %%
#algoritmo='ES'
#algoritmo='ES-proporcional'
#algoritmo='BMB'
#algoritmo='ILS'
#algoritmo='ILS-ES'
#algoritmo='ILS-ES-proporcional'

# %%
with open("software/salidas/"+algoritmo+".txt",'r') as f:
    lines= f.readlines()

lines=lines[1:]

i=0
while i < len(lines):
    ficheros.append(lines[i].replace('data/','').replace('\n',''))
    datos.append(list(map(float,lines[i+1].split('\t'))))
    i+=2

# %%
datos
# Out:
# [[7660.88, 0.017283],
#  [7772.47, 0.013603],
#  [7591.18, 0.01405],
#  [7707.75, 0.015932],
#  [7702.17, 0.015334],
#  [7714.32, 0.017715],
#  [7672.09, 0.014922],
#  [7705.26, 0.016767],
#  [7656.16, 0.014316],
#  [7636.03, 0.013425],
#  [10151566.026281, 0.204191],
#  [10142682.076739, 0.209332],
#  [10164738.443003, 0.203536],
#  [10133208.450619, 0.203854],
#  [10164812.427095, 0.207782],
#  [10145251.979101, 0.205104],
#  [10137104.785362, 0.204665],
#  [10128767.335839, 0.20431],
#  [10144259.477367, 0.204871],
#  [10142830.755806, 0.205124],
#  [40208739.0, 0.511763],
#  [62760313.0, 0.56673],
#  [62781454.0, 0.504105],
#  [62827242.0, 0.499241],
#  [90284193.0, 0.557551],
#  [22659579.0, 0.354045],
#  [90288483.0, 0.559854],
#  [22681498.0, 0.350276],
#  [40219034.0, 0.440523],
#  [40165010.0, 0.429584]]

# %%
df = pd.DataFrame({'File':[],'Diversity':[],'Time':[]})

# %%
for i in range(len(ficheros)):
    new_row={'File':ficheros[i][:-4],'Diversity':datos[i][0],'Time':datos[i][1]}
    df=df.append(new_row, ignore_index=True)

# %%
df.index=df.File
df.drop(columns=['File'],inplace=True)

# %%
new_index=['MDG-a_'+str(i)+'_n500_m50' for i in range(1,11)]
new_index=new_index+['MDG-b_'+str(i)+'_n2000_m200' for i in range(21,31)]
new_index=new_index+['MDG-c_'+str(i)+'_n3000_m300' for i in range(1,3)]
new_index=new_index+['MDG-c_'+str(i)+'_n3000_m400' for i in range(8,11)]
new_index=new_index+['MDG-c_'+str(i)+'_n3000_m500' for i in range(13,16)]
new_index=new_index+['MDG-c_'+str(i)+'_n3000_m600' for i in range(19,21)]

# %%
df=df.reindex(new_index)
df
# Out:
#                         Diversity      Time
# File
# MDG-a_1_n500_m50     7.772470e+03  0.013603
# MDG-a_2_n500_m50     7.591180e+03  0.014050
# MDG-a_3_n500_m50     7.707750e+03  0.015932
# MDG-a_4_n500_m50     7.702170e+03  0.015334
# MDG-a_5_n500_m50     7.714320e+03  0.017715
# MDG-a_6_n500_m50     7.672090e+03  0.014922
# MDG-a_7_n500_m50     7.705260e+03  0.016767
# MDG-a_8_n500_m50     7.656160e+03  0.014316
# MDG-a_9_n500_m50     7.636030e+03  0.013425
# MDG-a_10_n500_m50    7.660880e+03  0.017283
# MDG-b_21_n2000_m200  1.015157e+07  0.204191
# MDG-b_22_n2000_m200  1.014268e+07  0.209332
# MDG-b_23_n2000_m200  1.016474e+07  0.203536
# MDG-b_24_n2000_m200  1.013321e+07  0.203854
# MDG-b_25_n2000_m200  1.016481e+07  0.207782
# MDG-b_26_n2000_m200  1.014525e+07  0.205104
# MDG-b_27_n2000_m200  1.013710e+07  0.204665
# MDG-b_28_n2000_m200  1.012877e+07  0.204310
# MDG-b_29_n2000_m200  1.014426e+07  0.204871
# MDG-b_30_n2000_m200  1.014283e+07  0.205124
# MDG-c_1_n3000_m300   2.265958e+07  0.354045
# MDG-c_2_n3000_m300   2.268150e+07  0.350276
# MDG-c_8_n3000_m400   4.021903e+07  0.440523
# MDG-c_9_n3000_m400   4.016501e+07  0.429584
# MDG-c_10_n3000_m400  4.020874e+07  0.511763
# MDG-c_13_n3000_m500  6.276031e+07  0.566730
# MDG-c_14_n3000_m500  6.278145e+07  0.504105
# MDG-c_15_n3000_m500  6.282724e+07  0.499241
# MDG-c_19_n3000_m600  9.028419e+07  0.557551
# MDG-c_20_n3000_m600  9.028848e+07  0.559854

# %%
df.to_csv('results/'+algoritmo+'.csv')
