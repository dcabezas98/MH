# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
ficheros=[]
datos=[]

# %%
#algoritmo='ES'
#algoritmo='ES-proporcional'
#algoritmo='BMB'
#algoritmo='ILS'
#algoritmo='ILS-ES'
#algoritmo='ILS-ES-proporcional'

# %%
with open("software/salidas/"+algoritmo+".txt",'r') as f:
    lines= f.readlines()

lines=lines[1:]

i=0
while i < len(lines):
    ficheros.append(lines[i].replace('data/','').replace('\n',''))
    datos.append(list(map(float,lines[i+1].split('\t'))))
    i+=2

# %%
datos
# Out:
# [[7607.76, 0.016775],
#  [7652.61, 0.016814],
#  [7594.54, 0.017536],
#  [7609.11, 0.017072],
#  [7595.04, 0.016683],
#  [7569.35, 0.016891],
#  [7640.05, 0.01682],
#  [7627.97, 0.01699],
#  [7626.51, 0.016762],
#  [7644.04, 0.016843],
#  [10992646.684172, 0.188707],
#  [11008491.957505, 0.206581],
#  [10996482.095115, 0.202149],
#  [10985954.662907, 0.199789],
#  [11048174.607814, 0.192322],
#  [11018675.18979, 0.191056],
#  [11012434.128481, 0.180776],
#  [10983708.101072, 0.180872],
#  [10990956.494922, 0.181083],
#  [11004898.284888, 0.181337],
#  [42462343.0, 0.419439],
#  [65814180.0, 0.493883],
#  [65784136.0, 0.492989],
#  [65787442.0, 0.493035],
#  [94068914.0, 0.556569],
#  [24240331.0, 0.338768],
#  [94005467.0, 0.555894],
#  [24268957.0, 0.340644],
#  [42470830.0, 0.419749],
#  [42447268.0, 0.418926]]

# %%
df = pd.DataFrame({'File':[],'Diversity':[],'Time':[]})

# %%
for i in range(len(ficheros)):
    new_row={'File':ficheros[i][:-4],'Diversity':datos[i][0],'Time':datos[i][1]}
    df=df.append(new_row, ignore_index=True)

# %%
df.index=df.File
df.drop(columns=['File'],inplace=True)

# %%
new_index=['MDG-a_'+str(i)+'_n500_m50' for i in range(1,11)]
new_index=new_index+['MDG-b_'+str(i)+'_n2000_m200' for i in range(21,31)]
new_index=new_index+['MDG-c_'+str(i)+'_n3000_m300' for i in range(1,3)]
new_index=new_index+['MDG-c_'+str(i)+'_n3000_m400' for i in range(8,11)]
new_index=new_index+['MDG-c_'+str(i)+'_n3000_m500' for i in range(13,16)]
new_index=new_index+['MDG-c_'+str(i)+'_n3000_m600' for i in range(19,21)]

# %%
df=df.reindex(new_index)
df
# Out:
#                         Diversity      Time
# File
# MDG-a_1_n500_m50     7.652610e+03  0.016814
# MDG-a_2_n500_m50     7.594540e+03  0.017536
# MDG-a_3_n500_m50     7.609110e+03  0.017072
# MDG-a_4_n500_m50     7.595040e+03  0.016683
# MDG-a_5_n500_m50     7.569350e+03  0.016891
# MDG-a_6_n500_m50     7.640050e+03  0.016820
# MDG-a_7_n500_m50     7.627970e+03  0.016990
# MDG-a_8_n500_m50     7.626510e+03  0.016762
# MDG-a_9_n500_m50     7.644040e+03  0.016843
# MDG-a_10_n500_m50    7.607760e+03  0.016775
# MDG-b_21_n2000_m200  1.099265e+07  0.188707
# MDG-b_22_n2000_m200  1.100849e+07  0.206581
# MDG-b_23_n2000_m200  1.099648e+07  0.202149
# MDG-b_24_n2000_m200  1.098595e+07  0.199789
# MDG-b_25_n2000_m200  1.104817e+07  0.192322
# MDG-b_26_n2000_m200  1.101868e+07  0.191056
# MDG-b_27_n2000_m200  1.101243e+07  0.180776
# MDG-b_28_n2000_m200  1.098371e+07  0.180872
# MDG-b_29_n2000_m200  1.099096e+07  0.181083
# MDG-b_30_n2000_m200  1.100490e+07  0.181337
# MDG-c_1_n3000_m300   2.424033e+07  0.338768
# MDG-c_2_n3000_m300   2.426896e+07  0.340644
# MDG-c_8_n3000_m400   4.247083e+07  0.419749
# MDG-c_9_n3000_m400   4.244727e+07  0.418926
# MDG-c_10_n3000_m400  4.246234e+07  0.419439
# MDG-c_13_n3000_m500  6.581418e+07  0.493883
# MDG-c_14_n3000_m500  6.578414e+07  0.492989
# MDG-c_15_n3000_m500  6.578744e+07  0.493035
# MDG-c_19_n3000_m600  9.406891e+07  0.556569
# MDG-c_20_n3000_m600  9.400547e+07  0.555894

# %%
df.to_csv('results/'+algoritmo+'.csv')
